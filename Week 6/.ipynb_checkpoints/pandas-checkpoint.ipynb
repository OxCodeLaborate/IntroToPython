# %% [markdown]
# # What is pandas?

# %%
import pandas as pd
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# =====================================================================
#
# See http://pandas.pydata.org/ for full documentation. Otherwise, see the
# docstrings of the various objects in the pandas namespace:
#
# Series
# DataFrame
# Panel
# Index
# DatetimeIndex
# HDFStore
# bdate_range
# date_range
# read_csv
# read_fwf
# read_table
# ols

# %% [markdown]
# # The most important thing: DataFrames

# %%
namesAges = [
    ["Sally", 6], 
    ["Joe", 10],
    ["John", 7],
    ["Kelly", 8]
] # just a list of lists

df = pd.DataFrame(
    data = namesAges, 
    columns = ["Names", "Ages"]
)

# %%
df
# Out:
#    Names  Ages
# 0  Sally     6
# 1    Joe    10
# 2   John     7
# 3  Kelly     8

# %% [markdown]
# # Looking inside the DataFrame

# %% [markdown]
# ## Rows and columns

# %%
df.columns
# Out:
# Index(['Names', 'Ages'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ## Iterating

# %%
for column in df:
    print(column)
# Out:
# Names
# Ages

# %% [markdown]
# ## Indexing

# %%
df["Names"]
# Out:
# 0    Sally
# 1      Joe
# 2     John
# 3    Kelly
# Name: Names, dtype: object

# %%
df["Ages"]
# Out:
# 0     6
# 1    10
# 2     7
# 3     8
# Name: Ages, dtype: int64

# %% [markdown]
# ## df.loc[row, col]
#
# Accesses rows according to the ```df.index``` and columns according to ```df.columns```

# %%
df.loc[1]
# Out:
# Names    Joe
# Ages      10
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Names    John
# Ages        7
# Name: 2, dtype: object

# %%
df.loc[2, "Names"]
# Out:
# 'John'

# %%
df.loc[2, "Ages"]
# Out:
# 7

# %% [markdown]
# ## df.iloc[rowInt, columnInt]
#
# Same as loc, but it's all integer indexing.

# %%
df.iloc[2, 0]
# Out:
# 'John'

# %%
df.iloc[2, 1]
# Out:
# 7

# %% [markdown]
# ## df.shape and size

# %%
df.shape
# Out:
# (4, 2)

# %%
df.size
# Out:
# 8

# %% [markdown]
# # Changing values in a pd.DataFrame

# %%
df.loc[2, "Ages"]
# Out:
# 7

# %%
df.loc[2, "Ages"] += 10

# %%
df
# Out:
#    Names  Ages
# 0  Sally     6
# 1    Joe    10
# 2   John    17
# 3  Kelly     8

# %%
df.insert(loc = 2, value = ["Math", "Music", "Science", "Geography"], column = "Favorite Class")

# %%
df
# Out:
#    Names  Ages Favorite Class
# 0  Sally     6           Math
# 1    Joe    10          Music
# 2   John    17        Science
# 3  Kelly     8      Geography

# %% [markdown]
# # Converting into np.arrays

# %%
df.values
# Out:
# array([['Sally', 6, 'Math'],
#        ['Joe', 10, 'Music'],
#        ['John', 17, 'Science'],
#        ['Kelly', 8, 'Geography']], dtype=object)

# %%
df["Names"].values
# Out:
# array(['Sally', 'Joe', 'John', 'Kelly'], dtype=object)

# %% [markdown]
# ## Saving as csv

# %%
df.to_csv("NamesAndAges.csv")

# %%
import os
os.listdir('.') # Can you find it in your current directory?
# Out:
# ['.ipynb_checkpoints',
#  'boston.csv',
#  'Introduction to Numpy.ipynb',
#  'Keras.ipynb',
#  'Matplotlib.ipynb',
#  'NamesAndAges.csv',
#  'pandas.ipynb',
#  'Sklearn.ipynb',
#  'Slides.pptx']

# %% [markdown]
# # Opening csvs!

# %%
df2 = pd.read_csv("boston.csv") # This csv is in the current folder, so it's just that easy to open!
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001

# %% [markdown]
# The ```df.head()``` method returns the top 5 rows of the dataframe, so we can have a look at the dataset without having to scroll very much

# %% [markdown]
# # Some tougher stuff

# %% [markdown]
# ```df.sort()```

# %%
df2.sort("CRIM", ascending = True)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#           CRIM     ZN  INDUS  CHAS     NOX     RM         AGE      DIS  RAD  \
# 0     0.006320   18.0   2.31     0  0.5380  6.575   65.199997   4.0900    1
# 284   0.009060   90.0   2.97     0  0.4000  7.088   20.799999   7.3073    1
# 285   0.010960   55.0   2.25     0  0.3890  6.453   31.900000   7.3073    1
# 341   0.013010   35.0   1.52     0  0.4420  7.241   49.299999   7.0379    1
# 55    0.013110   90.0   1.22     0  0.4030  7.249   21.900000   8.6966    5
# 54    0.013600   75.0   4.00     0  0.4100  5.888   47.599998   7.3197    3
# 195   0.013810   80.0   0.46     0  0.4220  7.875   32.000000   5.6484    4
# 57    0.014320  100.0   1.32     0  0.4110  6.816   40.500000   8.3248    5
# 194   0.014390   60.0   2.93     0  0.4010  6.604   18.799999   6.2196    1
# 348   0.015010   80.0   2.01     0  0.4350  6.635   29.700001   8.3440    4
# 283   0.015010   90.0   1.21     1  0.4010  7.923   24.799999   5.8850    1
# 256   0.015380   90.0   3.75     0  0.3940  7.454   34.200001   6.3361    3
# 353   0.017090   90.0   2.02     0  0.4100  6.728   36.099998  12.1265    5
# 200   0.017780   95.0   1.47     0  0.4030  7.135   13.900000   7.6534    3
# 347   0.018700   85.0   4.15     0  0.4290  6.516   27.700001   8.5353    4
# 64    0.019510   17.5   1.38     0  0.4161  7.104   59.500000   9.2229    3
# 286   0.019650   80.0   1.76     0  0.3850  6.230   31.500000   9.0892    1
# 204   0.020090   95.0   2.68     0  0.4161  8.034   31.900000   5.1180    4
# 56    0.020550   85.0   0.74     0  0.4100  6.383   35.700001   9.1876    2
# 202   0.021770   82.5   2.03     0  0.4150  7.610   15.700000   6.2700    2
# 387  666  20.200001  396.899994  31.990000   7.400000
# 378  666  20.200001  396.899994  23.690001  13.100000
# 386  666  20.200001  396.899994  28.280001  10.500000
# 403  666  20.200001  396.899994  19.770000   8.300000
# 400  666  20.200001  396.899994  26.770000   5.600000
# 417  666  20.200001  127.360001  26.639999  10.400000
# 413  666  20.200001  210.970001  20.080000  16.299999
# 427  666  20.200001   18.820000  14.520000  10.900000
# 398  666  20.200001  396.899994  30.590000   5.000000
# 404  666  20.200001  329.459992  27.379999   8.500000
# 414  666  20.200001   88.269997  36.980000   7.000000
# 410  666  20.200001    2.600000  10.110000  15.000000
# 405  666  20.200001  384.970001  22.980000   5.000000
# 418  666  20.200001   16.450001  20.620001   8.800000
# 380  666  20.200001  396.899994  17.209999  10.400000
#
# [506 rows x 14 columns]

# %%
df2["DIS"] *= 1000

# %%
df2.loc[:, "DIS":].head()
# Out:
#            DIS  RAD  TAX         PT           B  LSTAT         MV
# 0  4090.000153    1  296  15.300000  396.899994   4.98  24.000000
# 1  4967.100143    2  242  17.799999  396.899994   9.14  21.600000
# 2  4967.100143    2  242  17.799999  392.829987   4.03  34.700001
# 3  6062.200069    3  222  18.700001  394.630005   2.94  33.400002
# 4  6062.200069    3  222  18.700001  396.899994   5.33  36.200001

# %% [markdown]
# Notice the change in the ```"DIS"``` column

# %% [markdown]
# We can use dtype to see the datatypes of each of the columns

# %%
for column in df2.columns:
    print(column, df2[column].dtype)
# Out:
# CRIM float64
# ZN float64
# INDUS float64
# CHAS int64
# NOX float64
# RM float64
# AGE float64
# DIS float64
# RAD int64
# TAX int64
# PT float64
# B float64
# LSTAT float64
# MV float64

# %% [markdown]
# You can use the ```df.describe``` method to learn more about the dataframe and its columns

# %%
df2.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE           DIS         RAD         TAX          PT  \
# count  506.000000    506.000000  506.000000  506.000000  506.000000
# mean    68.574901   3795.042696    9.549407  408.237154   18.455534
# std     28.148862   2105.710142    8.707259  168.537116    2.164946
# min      2.900000   1129.600048    1.000000  187.000000   12.600000
# 25%     45.025000   2100.174904    4.000000  279.000000   17.400000
# 50%     77.500000   3207.449913    5.000000  330.000000   19.050000
# 75%     94.074999   5188.425183   24.000000  666.000000   20.200001
# max    100.000000  12126.500130   24.000000  711.000000   22.000000
#
#                 B       LSTAT          MV
# count  506.000000  506.000000  506.000000
# mean   356.674030   12.653063   22.532806
# std     91.294863    7.141062    9.197104
# min      0.320000    1.730000    5.000000
# 25%    375.377487    6.950000   17.025000
# 50%    391.440002   11.360000   21.200001
# 75%    396.225006   16.954999   25.000000
# max    396.899994   37.970001   50.000000

# %%
df2.shape
# Out:
# (506, 14)

# %% [markdown]
# # More about this dataset if you're curious:
#
# https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html

# %% [markdown]
# Learn more about using panadas at the link below! It's a 10-minute tutorial!
#
# https://pandas.pydata.org/pandas-docs/stable/10min.html
